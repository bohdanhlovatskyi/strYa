# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
with open('euler_angles_2.txt') as file:
    data = file.readlines()
    
for idx, line in enumerate(data):
    line = line.split(', ')
    # line[0] = line[0].split()[1]
    data[idx] = [round(float(elm), 2) if idx else elm for idx, elm in enumerate(line)]


df = pd.DataFrame(data)

# %%
df = df[100:200]

# %%
# plt.plot(df[0], df[1])
plt.plot(df[0], df[2])
# plt.plot(df[0], df[3])
plt.show()
